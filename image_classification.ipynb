# %% [markdown]
# # Pytorch Image Classification

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image
from torch.autograd import Variable

plt.ion()   # interactive mode

# %% [markdown]
# ## Load and Normalize Data

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

#Change path with yours: This data dir contains stanford dogs dataset and cat dataset as mentioned in the README
data_dir = '/home/lucky/Dataset/Images/data_explore/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if device:
    print(device, "found, train data using GPU", )
else:
    print("Train data using CPU")
# Out:
# cuda:0 found, train data using GPU

# %% [markdown]
# ## Display 4 Images in Training Data Path, Randomly

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Finetuning the convnet
# #### Load a pretrained model and reset final fully connected layer.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# ## Train and Evaluate

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.3223 Acc: 0.8834
# val Loss: 0.0534 Acc: 0.9815
#
# Epoch 1/24
# ----------
# train Loss: 0.3366 Acc: 0.8803
# val Loss: 0.0329 Acc: 0.9889
#
# Epoch 2/24
# ----------
# train Loss: 0.3245 Acc: 0.8852
# val Loss: 0.0337 Acc: 0.9876
#
# Epoch 3/24
# ----------
# train Loss: 0.3187 Acc: 0.8870
# val Loss: 0.0673 Acc: 0.9768
#
# Epoch 4/24
# ----------
# train Loss: 0.3244 Acc: 0.8867
# val Loss: 0.0418 Acc: 0.9850
#
# Epoch 5/24
# ----------
# train Loss: 0.3231 Acc: 0.8856
# val Loss: 0.0877 Acc: 0.9681
#
# Epoch 6/24
# ----------
# train Loss: 0.3257 Acc: 0.8855
# val Loss: 0.0368 Acc: 0.9873
#
# Epoch 7/24
# ----------
# train Loss: 0.3140 Acc: 0.8865
# val Loss: 0.0921 Acc: 0.9648
#
# Epoch 8/24
# ----------
# train Loss: 0.3238 Acc: 0.8866
# val Loss: 0.0938 Acc: 0.9657
#
# Epoch 9/24
# ----------
# train Loss: 0.3420 Acc: 0.8843
# val Loss: 0.0401 Acc: 0.9865
#
# Epoch 10/24
# ----------
# train Loss: 0.3169 Acc: 0.8865
# val Loss: 0.1198 Acc: 0.9538
#
# Epoch 11/24
# ----------
# train Loss: 0.3303 Acc: 0.8854
# val Loss: 0.0670 Acc: 0.9751
#
# Epoch 12/24
# ----------
# train Loss: 0.3268 Acc: 0.8879
# val Loss: 0.0395 Acc: 0.9863
#
# Epoch 13/24
# ----------
# train Loss: 0.3132 Acc: 0.8913
# val Loss: 0.0792 Acc: 0.9729
#
# Epoch 14/24
# ----------
# train Loss: 0.3301 Acc: 0.8838
# val Loss: 0.0405 Acc: 0.9867
#
# Epoch 15/24
# ----------
# train Loss: 0.3216 Acc: 0.8861
# val Loss: 0.0402 Acc: 0.9868
#
# Epoch 16/24
# ----------
# train Loss: 0.3199 Acc: 0.8895
# val Loss: 0.1510 Acc: 0.9451
#
# Epoch 17/24
# ----------
# train Loss: 0.3306 Acc: 0.8856
# val Loss: 0.0435 Acc: 0.9834
#
# Epoch 18/24
# ----------
# train Loss: 0.3377 Acc: 0.8822
# val Loss: 0.0361 Acc: 0.9880
#
# Epoch 19/24
# ----------
# train Loss: 0.3329 Acc: 0.8858
# val Loss: 0.0626 Acc: 0.9782
#
# Epoch 20/24
# ----------
# train Loss: 0.3219 Acc: 0.8869
# val Loss: 0.0383 Acc: 0.9873
#
# Epoch 21/24
# ----------
# train Loss: 0.3061 Acc: 0.8899
# val Loss: 0.1337 Acc: 0.9510
#
# Epoch 22/24
# ----------
# train Loss: 0.3155 Acc: 0.8908
# val Loss: 0.0303 Acc: 0.9894
#
# Epoch 23/24
# ----------
# train Loss: 0.3159 Acc: 0.8874
# val Loss: 0.0376 Acc: 0.9855
#
# Epoch 24/24
# ----------
# train Loss: 0.3228 Acc: 0.8861
# val Loss: 0.0387 Acc: 0.9863
#
# Training complete in 77m 18s
# Best val Acc: 0.989371

# %% [markdown]
# ## Save Model
# #### Don't execute it if you have built the model, otherwise the model would be overwritten.

# %%
#Change path with yours
torch.save(model_ft.state_dict(), './models/cat_dog_model_ft.pth')

# %%
visualize_model(model_ft)

# %% [markdown]
# ## Load Model

# %%
#Change path with yours
path = './models/cat_dog_model_ft.pth'

model = model_ft

model.load_state_dict(torch.load(path))

# %% [markdown]
# ## ConvNet as fixed feature extractor

# %%
model_conv = torchvision.models.resnet18(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2)

model_conv = model_conv.to(device)
  
criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %% [markdown]
# ## Train and Evaluate

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.3377 Acc: 0.8771
# val Loss: 0.0385 Acc: 0.9864
#
# Epoch 1/24
# ----------
# train Loss: 0.3315 Acc: 0.8810
# val Loss: 0.0758 Acc: 0.9713
#
# Epoch 2/24
# ----------
# train Loss: 0.3311 Acc: 0.8824
# val Loss: 0.0452 Acc: 0.9846
#
# Epoch 3/24
# ----------
# train Loss: 0.3278 Acc: 0.8852
# val Loss: 0.0328 Acc: 0.9882
#
# Epoch 4/24
# ----------
# train Loss: 0.3234 Acc: 0.8863
# val Loss: 0.0286 Acc: 0.9899
#
# Epoch 5/24
# ----------
# train Loss: 0.3180 Acc: 0.8870
# val Loss: 0.0326 Acc: 0.9878
#
# Epoch 6/24
# ----------
# train Loss: 0.3196 Acc: 0.8859
# val Loss: 0.0424 Acc: 0.9852
#
# Epoch 7/24
# ----------
# train Loss: 0.2424 Acc: 0.9059
# val Loss: 0.0378 Acc: 0.9881
#
# Epoch 8/24
# ----------
# train Loss: 0.2332 Acc: 0.9085
# val Loss: 0.0476 Acc: 0.9861
#
# Epoch 9/24
# ----------
# train Loss: 0.2319 Acc: 0.9086
# val Loss: 0.0410 Acc: 0.9874
#
# Epoch 10/24
# ----------
# train Loss: 0.2286 Acc: 0.9097
# val Loss: 0.0380 Acc: 0.9893
#
# Epoch 11/24
# ----------
# train Loss: 0.2239 Acc: 0.9114
# val Loss: 0.0458 Acc: 0.9862
#
# Epoch 12/24
# ----------
# train Loss: 0.2293 Acc: 0.9095
# val Loss: 0.0406 Acc: 0.9884
#
# Epoch 13/24
# ----------
# train Loss: 0.2223 Acc: 0.9121
# val Loss: 0.0362 Acc: 0.9891
#
# Epoch 14/24
# ----------
# train Loss: 0.2189 Acc: 0.9125
# val Loss: 0.0448 Acc: 0.9867
#
# Epoch 15/24
# ----------
# train Loss: 0.2196 Acc: 0.9107
# val Loss: 0.0550 Acc: 0.9826
#
# Epoch 16/24
# ----------
# train Loss: 0.2233 Acc: 0.9112
# val Loss: 0.0393 Acc: 0.9893
#
# Epoch 17/24
# ----------
# train Loss: 0.2200 Acc: 0.9121
# val Loss: 0.0414 Acc: 0.9882
#
# Epoch 18/24
# ----------
# train Loss: 0.2189 Acc: 0.9111
# val Loss: 0.0417 Acc: 0.9879
#
# Epoch 19/24
# ----------
# train Loss: 0.2210 Acc: 0.9123
# val Loss: 0.0432 Acc: 0.9878
#
# Epoch 20/24
# ----------
# train Loss: 0.2223 Acc: 0.9100
# val Loss: 0.0405 Acc: 0.9881
#
# Epoch 21/24
# ----------
# train Loss: 0.2235 Acc: 0.9112
# val Loss: 0.0394 Acc: 0.9889
#
# Epoch 22/24
# ----------
# train Loss: 0.2264 Acc: 0.9089
# val Loss: 0.0381 Acc: 0.9883
#
# Epoch 23/24
# ----------
# train Loss: 0.2156 Acc: 0.9145
# val Loss: 0.0389 Acc: 0.9896
#
# Epoch 24/24
# ----------
# train Loss: 0.2184 Acc: 0.9133
# val Loss: 0.0386 Acc: 0.9887
#
# Training complete in 78m 36s
# Best val Acc: 0.989927

# %% [markdown]
# ## Save Model

# %%
#Change path with yours
path = './models/cat_dog_model_conv.pth'

torch.save(model_conv.state_dict(), path)

# %% [markdown]
# ## Load Model

# %%
#Change path with yours
path = './models/cat_dog_model_conv.pth'

model = model_conv

model.load_state_dict(torch.load(path))

# %%
# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
visualize_model(model)
